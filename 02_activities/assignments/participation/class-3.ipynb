# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = 'lower right',
          frameon = True,
          fontsize = 12, 
          ncol = 2, 
          shadow = True)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "upper left",
          bbox_to_anchor =(1, 1))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "lower left",
          bbox_to_anchor =(1, 1))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95, "This value is important!",
        ha = 'center',
        color = 'red',
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95, "This value is important!",
        ha = 'left',
        color = 'red',
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData )
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes )
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure )
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
            xytext = (20, 94), arrowprops=dict(facecolor='black'))
# Out:
#   Cell In[16], line 7
#     xytext = (20, 94), arrowprops=dict(facecolor='black'))
#     ^
# SyntaxError: keyword argument repeated: xytext

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

#ax.yaxis.set_major_locator(plt.NullLocator())
#ax.xaxis.set_major_formatter(plt.NullFormatter())

#ax.xaxis.set_major_locator(plt.MaxNLocator(3)) 

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

plt.xticks(rotation=45, ha='right', fontsize = 12, font = "serif" )
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1 = {' family':'serif','color':'indigo'}

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

plt.xticks(rotation=45, ha='right', fontsize = 12, font = "serif" )

plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 8
#       4 ax.scatter(x,y1)
#       6 plt.xticks(rotation=45, ha='right', fontsize = 12, font = "serif" )
# ----> 8 plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\pyplot.py:4407, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4398 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4399 def xlabel(
#    4400     xlabel: str,
#    (...)   4405     **kwargs,
#    4406 ) -> Text:
# -> 4407     return gca().set_xlabel(
#    4408         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4409     )
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\axes\_base.py:3645, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3638     x = {
#    3639         'left': 0,
#    3640         'center': 0.5,
#    3641         'right': 1,
#    3642     }[loc]
#    3643     kwargs.update(x=x, horizontalalignment=loc)
# -> 3645 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\axis.py:1901, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1899 self.label.set_text(label)
#    1900 if fontdict is not None:
# -> 1901     self.label.update(fontdict)
#    1902 self.label.update(kwargs)
#    1903 self.stale = True
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property ' family'

# %%
font1 = {' family':'serif','color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 6
#       4 ax.scatter(x,y2, label = "Person 2")
#       5 ax.legend(loc='lower right')
# ----> 6 plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\pyplot.py:4407, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4398 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4399 def xlabel(
#    4400     xlabel: str,
#    (...)   4405     **kwargs,
#    4406 ) -> Text:
# -> 4407     return gca().set_xlabel(
#    4408         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4409     )
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\axes\_base.py:3645, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3638     x = {
#    3639         'left': 0,
#    3640         'center': 0.5,
#    3641         'right': 1,
#    3642     }[loc]
#    3643     kwargs.update(x=x, horizontalalignment=loc)
# -> 3645 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\axis.py:1901, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1899 self.label.set_text(label)
#    1900 if fontdict is not None:
# -> 1901     self.label.update(fontdict)
#    1902 self.label.update(kwargs)
#    1903 self.stale = True
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File c:\Users\admin\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property ' family'

# %%
plt.style.use('grayscale') 

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
plt.style.use('classic') 

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
plt.style.use('default') 

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2,
                              nrows=1,
                              figsize=(7, 3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2,
                              nrows=1,
                              figsize=(7, 3))

font1 = {'family': 'serif', 'size':40}
font2 = {'family': 'serif', 'size':40}

ax1.scatter(x1, y1, marker = 'o', color = 'red')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7, 4))

someaxes['ax1'].scatter(x1,y1)
someaxes['ax2'].bar(x1,y1)
someaxes['ax3'].plot(x1,y1)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7, 4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes['ax1'].set_xlabel('A Big Label', fontsize = 18)
someaxes['ax2'].set_xlabel('Another Label', fontsize = 18)
someaxes['ax3'].set_xlabel('Label 2: 2 Fast 2 Furious', fontsize = 18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

fig, ax = plt.subplots(figsize=(7, 3))
ax.bar(x,y1, color = "indigo")
ax.plot(x,y2, color = "red")

# %%
y2_sd = np.std(y2) 

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# %%
y2_sd = np.std(y2) 

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax.errorbar(x, y2, yerr = y2_sd, fmt = "none", 
            ecolor= "indigo",
            elinewidth= 4,
            capsize = 6,
            capthick= 4,
            errorevery = 2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image 
import requests 
from io import BytesIO 

response = requests.get('https://static.wikia.nocookie.net/the-ultimate-good/images/3/3d/Luffy.png/revision/latest?cb=20230417200546')
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35])

ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (np.float64(-0.5), np.float64(410.5), np.float64(999.5), np.float64(-0.5))
