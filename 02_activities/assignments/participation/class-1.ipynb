# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
# To make sample data to have something to plot

np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50) 

fig, ax = plt.subplots(figsize=(5,3)) # basic scatter plot
#ax.scatter(x,y)
#ax.bar(x,y)
ax.barh(x,y)
ax.plot(x,y)
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# modifying labels and titles 
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5,3)) # modifying the graph by editing the axis, but keeping the figure and axis same 
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict=font1, loc = 'left') # adding axis labels and titles 
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y, marker='*', color = 'indigo')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker='*', color = 'indigo', linestyle = '--', linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,
        marker='*', 
        markersize = 12, 
        color = '#7425b9', 
        linestyle = '--', 
        linewidth = 2, 
        markeredgecolor = '#fa9359',  
        markerfacecolor = '#000000' )

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,
        marker='*', 
        markersize = 12, 
        color = '#7425b9', 
        linestyle = '--', 
        linewidth = 2, 
        markeredgecolor = '#fa9359',  
        markerfacecolor = '#000000' ) 
ax.grid(axis = 'y')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,
        marker='*', 
        markersize = 12, 
        color = '#7425b9', 
        linestyle = '--', 
        linewidth = 2, 
        markeredgecolor = '#fa9359',  
        markerfacecolor = '#000000' ) 
ax.grid(axis = 'x')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,
        marker='*', 
        markersize = 12, 
        color = "#5e2194", 
        linestyle = '--', 
        linewidth = 2, 
        markeredgecolor = "#f35e08",  
        markerfacecolor = '#000000' ) 
ax.grid(color ='blue', linewidth = 2, linestyle = 'dotted')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Data
my_variable = np.random.normal(loc=10, scale=5, size=100)

# Plot
sns.swarmplot(y=my_variable)
plt.show() # Display the chart

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=("Python Python Python Matplotlib")

# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Libraries
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
 
# Data set
url = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/mtcars.csv'
df = pd.read_csv(url)
df = df.set_index('model')
 
# Calculate the distance between each sample
Z = linkage(df, 'ward')
 
# Plot with Custom leaves
dendrogram(Z, leaf_rotation=90, leaf_font_size=8, labels=df.index)

# Show the graph
plt.show()
